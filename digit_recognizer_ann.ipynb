# %%
# !pip install opendatasets

# %%
import opendatasets as od
od.download('https://www.kaggle.com/datasets/oddrationale/mnist-in-csv')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: shreshthaaaroy
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/oddrationale/mnist-in-csv
# ...
# 100%|██████████| 15.2M/15.2M [00:01<00:00, 14.0MB/s]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_csv('/content/mnist-in-csv/mnist_train.csv')
test = pd.read_csv('/content/mnist-in-csv/mnist_test.csv')

# %%
X_train = train.drop('label', axis=1)
X_test = test.drop('label', axis=1)

y_train = train['label']
y_test = test['label']

# %%
X_train_sc = X_train/255.0
X_test_sc = X_test/255.0

# %%
y_train_cat = to_categorical(y_train, num_classes=10)
y_test_cat = to_categorical(y_test, num_classes=10)

# %%
model = Sequential([
    Dense(256, input_shape=(784,), activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train_sc, y_train_cat, epochs=20, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9312 - loss: 0.2255 - val_accuracy: 0.9642 - val_loss: 0.1102
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9710 - loss: 0.0951 - val_accuracy: 0.9760 - val_loss: 0.0820
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9792 - loss: 0.0672 - val_accuracy: 0.9768 - val_loss: 0.0800
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9837 - loss: 0.0511 - val_accuracy: 0.9780 - val_loss: 0.0767
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9866 - loss: 0.0420 - val_accuracy: 0.9802 - val_loss: 0.0766
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9896 - loss: 0.0332 - val_accuracy: 0.9740 - val_loss: 0.0854
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9905 - loss: 0.0286 - val_accuracy: 0.9773 - val_loss: 0.0824
# Epoch 8/20
# ...

# %%
loss, acc = model.evaluate(X_test_sc, y_test_cat, verbose=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9813 - loss: 0.1015

# %%
print("Bias check (must NOT be zero):", model.layers[0].get_weights()[1][:3])
print("Final val_accuracy:", history.history['val_accuracy'][-1])
# Out:
# Bias check (must NOT be zero): [0.0423831  0.00685185 0.05994469]
# Final val_accuracy: 0.9831666946411133

# %%
model.save("model.keras")
print("Saved!")
# Out:
# Saved!

# %%
from tensorflow.keras.models import load_model
import numpy as np

verify = load_model("model.keras")

b = verify.layers[0].get_weights()[1][:3]
print("Saved model bias check:", b)
print("All zero?", np.allclose(b, 0))
# Out:
# Saved model bias check: [0.0423831  0.00685185 0.05994469]
# All zero? False

# %%
from google.colab import files
files.download("model.keras")
